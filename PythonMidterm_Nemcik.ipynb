# %%
import requests
from bs4 import BeautifulSoup
from time import sleep
from tqdm import tqdm
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Circle

# %%
def getSoup(link): #setting the get link function
    sleep(0.05) 
    r = requests.get(link)
    r.encoding = 'UTF-8'
    return BeautifulSoup(r.text,'lxml')

# %%
class Midterm(): #setting the class
    def __init__(self,link):
        self.link = link
        self.request = requests.get(link)
        self.request.encoding='UTF-8'
        self.soup = BeautifulSoup(self.request.text,'lxml')
        
    def scrape(self):
        lis = self.soup.find('span',{'id':'Unseen_University_and_the_Wizards'}).parent.previous.previous.parent.parent.parent.find_all('li')
        links = ['http://wiki.lspace.org' + ls.a['href'] for ls in lis] #establishing the links to the character pages
        names = [] #establishing empty lists to store names and books into
        books = []
        
        for lk in links: #iterating over links  to get the names of the characters
            nm = lk.split('/')[-1] #getting the names
            nm = nm.replace('_', " ") #getting rid of _
            names.append(nm) #apending the names
            books_temp = []
            soup = getSoup(lk) #getting the soup of the character webpages
            tds = soup.find('a',{'title':'Bibliography'}).parent.parent.parent #looking for the html with books of appearences
            for td in soup.findAll(title=re.compile("Book:")): #getting the books
                books_temp.append(td.text)
            clean = []
            [clean.append(x) for x in books_temp if x not in clean] 
            books.append(clean) #appending the books to the list of lists
            
        df_pratchett = pd.DataFrame({'Name': names, 'Books': books}) #creating the dataframe 
        return df_pratchett #returning the dataframe
    
    def count(self):
        df_pratchett = self.scrape() #getting the dataframe from other method
        counter = 0
        for sublist in list(df_pratchett['Books']): #iterating over the dataframe to see on which rows the Mean at Arms are
            if "Men at Arms" in sublist:
                counter += 1
        
        return "%s major characters appear in Men at Arms." %counter

# %%
mid = Midterm('http://wiki.lspace.org/mediawiki/List_of_Pratchett_characters')
mid.scrape() #showing the outcome - dataframe
# Out:
#                                             Name  \
# 0                                      Mrs. Cake
# 1                                     Fred Colon
# 2                      Mrs. Marietta Cosmopilite
# 3                                       Detritus
# 4                      Cut-Me-Own-Throat Dibbler
# 5                                          Dorfl
# 6                                Rufus Drumknott
# 7                                        Gaspode
# 8                         Carrot Ironfoundersson
# 9                               Leonard of Quirm
# 10                           Cheery Littlebottom
# 11                                   Nobby Nobbs
# 12                             Lady Sybil Ramkin
# 13                                  Foul Ole Ron
# 14                                      Reg Shoe
# 15                                     Mr. Slant
# 16                       Angua von %C3%9Cberwald
# 17                             Havelock Vetinari
# 18                                  Samuel Vimes
# 19  Visit-the-Infidel-with-Explanatory-Pamphlets
# 20                                     Willikins
#
#                                                 Books
# 0   [Reaper Man, Men at Arms, Jingo, Going Postal,...
# 1   [Guards! Guards!, Men at Arms, Soul Music, Fee...
# 2   [Soul Music, Moving Pictures, Small Gods, Thie...
# 3   [Guards! Guards!, Moving Pictures, Men at Arms...
# 4   [Guards! Guards!, Moving Pictures, Reaper Man,...
# 5   [Feet of Clay, Jingo, The Fifth Elephant, Thud...
# 6   [Unseen Academicals, Feet of Clay, Jingo, The ...
# 7   [Moving Pictures, Men at Arms, The Fifth Eleph...
# 8   [Guards! Guards!, Men at Arms, Feet of Clay, J...
# 9   [Wyrd Sisters, Men at Arms, Jingo, The Fifth E...
# 10  [Feet of Clay, Jingo, The Fifth Elephant, Thud...
# 11  [Moving Pictures, Hogfather, Maskerade, Soul M...
# 12  [Night Watch, Guards! Guards!, Men at Arms, Fe...
# 13  [Men at Arms, Feet of Clay, Hogfather, Jingo, ...
# 14  [Reaper Man, Monstrous Regiment, Jingo, Raisin...
# 15  [Making Money, Feet of Clay, Jingo, The Truth,...
# 16  [I Shall Wear Midnight, Men at Arms, Feet of C...
# 17  [Men at Arms, Sourcery, Guards! Guards!, Movin...
# 18  [Thud!, Guards! Guards!, Men at Arms, Feet of ...
# 19  [Feet of Clay, Jingo, Hogfather, The Fifth Ele...
# 20  [Men at Arms, Feet of Clay, Jingo, The Fifth E...

# %%
mid.count()
